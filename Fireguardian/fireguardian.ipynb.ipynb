# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="VVhCRk7eOYIm4VzVUOkQ")
project = rf.workspace("brad-dwyer").project("wildfire-smoke")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.5/81.5 kB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Wildfire-Smoke-1 in yolov8:: 100%|██████████| 1486/1486 [00:00<00:00, 3868.32it/s]

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 901.3/901.3 kB 13.1 MB/s eta 0:00:00
# ...

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=/content/Wildfire-Smoke-1/data.yaml epochs=51 imgsz=256
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100% 6.25M/6.25M [00:00<00:00, 177MB/s]
# Ultralytics 8.3.50 🚀 Python-3.10.12 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
from ultralytics import YOLO

# Load a COCO-pretrained YOLOv8n model
model = YOLO("yolov8n.pt")

# Display model information (optional)
model.info()

# Train the model on the COCO8 example dataset for 100 epochs
results = model.train(data="/content/Wildfire-Smoke-1/data.yaml", epochs=51, imgsz=256)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 16.6MB/s]
# YOLOv8n summary: 225 layers, 3,157,200 parameters, 0 gradients, 8.9 GFLOPs
# Ultralytics 8.3.51 🚀 Python-3.10.12 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
#now checking the model
# !yolo task=detect mode=predict model='/content/runs/detect/train/weights/best.pt' conf=0.25 source='/content/Wildfire-Smoke-1/test/images/ck0kcoc8ik6ni0848clxs0vif_jpeg.rf.8b4629777ffe1d349cc970ee8af59eac.jpg'
# Out:
# Ultralytics 8.3.51 🚀 Python-3.10.12 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /content/Wildfire-Smoke-1/test/images/ck0kcoc8ik6ni0848clxs0vif_jpeg.rf.8b4629777ffe1d349cc970ee8af59eac.jpg: 192x256 1 smoke, 118.9ms
# Speed: 1.3ms preprocess, 118.9ms inference, 2.7ms postprocess per image at shape (1, 3, 192, 256)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from PIL import Image # import the Image class from the PIL library

image = Image.open('/content/runs/detect/predict/ck0kcoc8ik6ni0848clxs0vif_jpeg.rf.8b4629777ffe1d349cc970ee8af59eac.jpg')

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480>

# %%
#checking other image
# !yolo task=detect model='/content/runs/detect/train/weights/best.pt' conf=0.25 source='/content/Wildfire-Smoke-1/test/images/ck0l8cfmgahkk0838nbgj26un_jpeg.rf.9346ac5d03cd252adb085d4b6b798779.jpg'
# Out:
# WARNING ⚠️ 'mode' argument is missing. Valid modes are {'train', 'track', 'val', 'benchmark', 'export', 'predict'}. Using default 'mode=train'.
# WARNING ⚠️ 'data' argument is missing. Using default 'data=coco8.yaml'.
# Ultralytics 8.3.51 🚀 Python-3.10.12 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
image2 = Image.open('/content/runs/detect/predict4/ck0khrg9xan7u0721mn5rxpzo_jpeg.rf.1f545d6c898ea9bad6147d7833f9b83f.jpg')

# %%
image2
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480>

# %%
# !yolo task=detect mode=predict model='/content/runs/detect/train4/weights/best.pt' conf=0.25 source='/content/Wildfire-Smoke-1/test/images/ck0kdhymna0b10721v4wntit8_jpeg.rf.a08e34d04fb672ce6cf8e94e810ec81d.jpg'
# Out:
# Ultralytics 8.3.51 🚀 Python-3.10.12 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /content/Wildfire-Smoke-1/test/images/ck0kdhymna0b10721v4wntit8_jpeg.rf.a08e34d04fb672ce6cf8e94e810ec81d.jpg: 192x256 (no detections), 78.9ms
# Speed: 1.3ms preprocess, 78.9ms inference, 2.3ms postprocess per image at shape (1, 3, 192, 256)
# Results saved to runs/detect/predict3
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
image3 = Image.open('/content/runs/detect/predict4/ck0khu2xz94nj070165dkfirk_jpeg.rf.d511cbdb4c1162cf08d710561abef2b3.jpg')

# %%
image3
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480>

# %%
# !yolo task=detect mode=predict model='/content/runs/detect/train4/weights/best.pt' conf=0.25 source='/content/Wildfire-Smoke-1/test/images'
# Out:
# Ultralytics 8.3.51 🚀 Python-3.10.12 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/74 /content/Wildfire-Smoke-1/test/images/ck0kcoc8ik6ni0848clxs0vif_jpeg.rf.8b4629777ffe1d349cc970ee8af59eac.jpg: 192x256 4 smokes, 51.2ms
# image 2/74 /content/Wildfire-Smoke-1/test/images/ck0kd4afx8g470701watkwxut_jpeg.rf.bb5a1f2c2b04be20c948fd3c5cec33ff.jpg: 192x256 1 smoke, 40.4ms
# image 3/74 /content/Wildfire-Smoke-1/test/images/ck0kdhymna0b10721v4wntit8_jpeg.rf.a08e34d04fb672ce6cf8e94e810ec81d.jpg: 192x256 (no detections), 34.9ms
# image 4/74 /content/Wildfire-Smoke-1/test/images/ck0kepbs9kdym0848hgpcf3y9_jpeg.rf.d0a63becb54a83b6b026f4b38a42933b.jpg: 192x256 4 smokes, 36.2ms
# image 5/74 /content/Wildfire-Smoke-1/test/images/ck0kewsaha6hh07215jgx1bp2_jpeg.rf.1a375d20560d0de016bb524921f7b2a9.jpg: 192x256 (no detections), 31.8ms
# ...

# %%
image4 = Image.open('/content/runs/detect/predict4/ck0l8cfmgahkk0838nbgj26un_jpeg.rf.9346ac5d03cd252adb085d4b6b798779.jpg')

# %%
image4
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480>

# %%
# !zip -r runs.zip runs
# Out:
#   adding: runs/ (stored 0%)
#   adding: runs/detect/ (stored 0%)
#   adding: runs/detect/train/ (stored 0%)
#   adding: runs/detect/train/results.png (deflated 7%)
#   adding: runs/detect/train/val_batch0_labels.jpg (deflated 13%)
#   adding: runs/detect/train/val_batch0_pred.jpg (deflated 12%)
#   adding: runs/detect/train/F1_curve.png (deflated 16%)
#   adding: runs/detect/train/labels.jpg (deflated 32%)
#   adding: runs/detect/train/train_batch1353.jpg (deflated 9%)
#   adding: runs/detect/train/events.out.tfevents.1734529458.974ab87921d1.275.0 (deflated 90%)
#   adding: runs/detect/train/weights/ (stored 0%)
#   adding: runs/detect/train/weights/best.pt (deflated 9%)
#   adding: runs/detect/train/weights/last.pt (deflated 9%)
#   adding: runs/detect/train/R_curve.png (deflated 16%)
#   adding: runs/detect/train/train_batch0.jpg (deflated 2%)
#   adding: runs/detect/train/results.csv (deflated 61%)
#   adding: runs/detect/train/train_batch1354.jpg (deflated 6%)
# ...

# %%
from google.colab import files
files.download('/content/runs.zip')
